# %%
import requests
from fake_useragent import UserAgent
import bs4 as bs
ua = UserAgent()

# %%
"https://hunter.io/email-finder"

# %%
r = requests.get("https://hunter.io/find/magellanstrategy.com/Chris%20Cavanaugh", headers={'User-Agent': ua.random})
r
# Out:
# <Response [200]>

# %%
soup = bs.BeautifulSoup(r.text,'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title>Email Finder: Chris Cavanaugh at magellanstrategy.com • Hunter</title>
# <meta content="Click to see the email address." name="description"/>
# <link href="https://hunter.io/email-finder/magellanstrategy.com/Chris%20Cavanaugh" rel="canonical"/>
# <meta content="noindex, follow" name="robots"/>
# <script>
#   window.rails_env = "production"
# </script>
# <script>
# //<![CDATA[
# window.gon={};
# //]]>
# </script>
# <script defer="" src="/libs/handlebars-4.4.2.min.js" type="text/javascript"></script>
# <script data-turbolinks-track="reload" defer="defer" src="https://hunter.io/assets/application-a5c9d2acb7c99e1ea02a96d0e5003a6fc88697342c357f8779ec51ac805bf906.js"></script>
# <script data-turbolinks-track="reload" defer="defer" src="https://hunter.io/packs/js/application-common-ed273ebd59337612c2a2.js"></script>
# ...

# %%
soup.find_all("email-container")
# Out:
# []

# %%
print(soup.find('div', attrs={'class':"email-container"}))
# Out:
# None
