# %%
import LoadTweets

# %%
LoadTweets.LoadingTweets("futurecrimes")
# Out:
# futurecrimes 201 tweets downloaded
# futurecrimes 400 tweets downloaded
# futurecrimes 599 tweets downloaded
# futurecrimes 798 tweets downloaded
# futurecrimes 996 tweets downloaded
# futurecrimes 1195 tweets downloaded
# futurecrimes 1391 tweets downloaded
# futurecrimes 1588 tweets downloaded
# futurecrimes 1788 tweets downloaded
# futurecrimes 1987 tweets downloaded
# futurecrimes 2186 tweets downloaded
# futurecrimes 2386 tweets downloaded
# futurecrimes 2586 tweets downloaded
# futurecrimes 2780 tweets downloaded
# futurecrimes 2980 tweets downloaded
# futurecrimes 3180 tweets downloaded
# futurecrimes 3225 tweets downloaded
# futurecrimes 3225 tweets downloaded
# UPDATED
# DOWNLOADED: 0.32 %
# DOWNLOADED: 0.63 %
# DOWNLOADED: 0.95 %
# DOWNLOADED: 1.27 %
# DOWNLOADED: 1.59 %
# DOWNLOADED: 1.9 %
# DOWNLOADED: 2.22 %
# DOWNLOADED: 2.54 %
# DOWNLOADED: 2.86 %
# DOWNLOADED: 3.17 %
# DOWNLOADED: 3.49 %
# DOWNLOADED: 3.81 %
# DOWNLOADED: 4.13 %
# DOWNLOADED: 4.44 %
# ...

# %%
# !zip -r BrettEwing.zip media/0010202

# %%
import numpy as np

# %%
find_user = "futurecrimes"
a = np.load("TwitteMediaDataBase.npy", allow_pickle=True)
for i in a:
    if i[0] == find_user:
        print(i[2], i[1])
# Out:
# 2019-01-26 18:30:27 1089229093172736000
# 2018-12-19 10:19:35 1075334825404391424
# 2018-09-22 02:11:42 1043321912821047296
# 2018-09-20 03:07:40 1042611220539273216
# 2018-05-28 04:03:50 1000950752041299968
# 2018-04-24 17:31:58 988832937775808512
# 2018-04-15 23:02:59 985654748123549696
# 2018-03-22 14:45:39 976832282165170176
# 2018-03-21 02:52:19 976290379015233537
# 2018-03-13 14:20:09 973564372588019713
# 2018-02-27 18:46:22 968557937978322944
# 2018-02-19 02:19:44 965410543900200960
# 2018-02-19 00:13:39 965378811813597184
# 2018-02-15 03:58:55 963985951721586694
# 2018-01-14 05:18:04 952409459564847106
# 2018-01-01 02:10:56 947651321586270208
# 2017-12-29 05:18:39 946611399202979840
# 2017-11-06 15:31:54 927559174132609024
# 2017-10-31 05:24:02 925231870672957440
# 2017-10-21 14:09:55 921740336052895744
# 2017-10-12 16:46:33 918518259703603201
# 2017-10-12 16:31:52 918514568153980929
# 2017-10-10 18:33:32 917820409856139264
# 2017-10-07 04:59:30 916528385391706113
# ...

# %%
import os

# %%
check = [row[:-4] for row in os.listdir("check")]
check
# Out:
# ['1254927609693196289',
#  '1253356039250067457',
#  '1172116027276177409',
#  '1161304425404731392',
#  '1244053146135072772',
#  '1121502193780129794',
#  '1159069889212092416',
#  '1250580122081669120',
#  '1131580125668098048',
#  '1251119688576372737',
#  '1128974420473724928',
#  '1249795716681207809',
#  '1262733662212231169',
#  '1230259693722927104',
#  '1238277011119931393',
#  '1263296421584867329',
#  '1252415857352863745',
#  '1130666461108809728',
#  '1260927236351328288',
#  '1227411975493292034',
#  '1246146021039710210',
#  '1225408138913947648',
#  '1138931751953342464',
#  '1247625020823801862',
#  '1158704421460750336',
#  '1264715880677756929',
#  '1248722628837335044',
#  '1250400993604448256',
#  '1132755650348560384',
#  '1127181130598318080',
#  '1225596174171766784',
#  '1135223017603305473',
#  '1131584675716182016',
#  '1242576892244393986',
#  '1253432900747268097',
#  '1152636047555268608',
#  '1150458080435539975',
#  '1217995662924496896',
# ...

# %%
for i in a:
    if i[1] in check:
        print(i[2])
# Out:
# 2020-05-25 00:32:17
# 2020-05-21 02:31:52
# 2020-05-19 13:15:40
# 2020-05-14 13:37:34
# 2020-05-11 11:47:27
# 2020-05-06 22:14:35
# 2020-05-06 11:35:57
# 2020-04-28 12:23:36
# 2020-04-28 00:17:12
# 2020-04-23 21:17:45
# 2020-04-23 16:12:20
# 2020-04-21 01:56:23
# 2020-04-17 12:05:53
# 2020-04-16 00:21:50
# 2020-04-15 12:30:02
# 2020-04-13 20:24:53
# 2020-04-10 21:20:49
# 2020-04-07 20:39:19
# 2020-04-03 18:42:18
# 2020-03-29 00:05:58
# 2020-03-24 22:19:51
# 2020-03-13 01:33:40
# 2020-02-19 22:35:42
# 2020-02-12 01:59:53
# 2020-02-07 01:44:33
# 2020-02-06 13:17:21
# 2020-01-17 02:22:49
# 2019-10-17 11:19:51
# 2019-09-12 11:53:32
# 2019-08-13 15:52:05
# 2019-08-07 11:52:50
# 2019-08-06 11:40:36
# 2019-07-20 17:47:03
# 2019-07-15 11:16:39
# 2019-07-14 17:32:35
# 2019-06-28 02:13:24
# 2019-06-12 22:11:04
# 2019-06-02 16:33:53
# 2019-05-26 21:09:27
# 2019-05-23 15:36:25
# 2019-05-23 15:18:20
# 2019-05-21 02:47:45
# 2019-05-16 10:44:11
# 2019-05-13 10:06:40
# 2019-05-12 11:54:46
# ...
