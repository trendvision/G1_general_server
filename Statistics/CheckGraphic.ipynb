# %%
from CheckGraphic import CheckGraphicID

# %%
# 5f00a24b2e1101f72cf2f593

# %%
bson_id = "5f45af5866e65ac210fc1367"
a = CheckGraphicID(bson_id)
print(a)
# Out:
# new collection
# https://si.wsj.net/public/resources/images/B3-EH284_Dshot_NS_20190618023230.png
# ...

# %%
 'bert_tags': ['e-commerce', 'internet', 'retail', 'social']
'entity_prepared': ['coffee', 'commodities', 'us']

# %%
db_client["tweets_pipeline_v2"].find({"$or": [{"status":"pipelined"},
#                                                            {"status":"graphicone_feed"}
                                                      ],
                                                       'source': 'sec',
#                                                    'approved_timestamp': {'$gte': end_date, '$lte': start_date},
                                                   }).count()
# Out:
# 26

# %%
import urllib.request
from PIL import Image

# %%
(2404, 1944)
(299, 167)
(326, 167)

# %%
def filterImageBySize(size):
    width, height = size
    if (width >= 250 and width <= 2000) and (height >= 300 and height <= 2000):
        return True
    else:
        return False

# %%
for i in db_client["tweets_pipeline_v2"].find(
                                                {
#                                                 "$or": [
#                                                     {"status":"pipelined"},
#                                                            {"status":"graphicone_feed"}
#                                                       ],
                                                       'source': 'sec',
#                                                    'approved_timestamp': {'$gte': end_date, '$lte': start_date},
                                                   },
    no_cursor_timeout=True):
    try:
        image = Image.open(urllib.request.urlopen(i['img_urls']))
        filterResult = filterImageBySize(image.size)
        if not filterResult:
            print(image.size)
            print(i['_id'])
            print(i['entity_prepared']+i["bert_tags"])    
            CheckGraphicID(i['_id'])
            print()
            print()
    except Exception as err:
        print(err)
# Out:
# (517, 249)
# 5f08704fc11778bb4a9dd5a6
# 'entity_prepared'
# (386, 287)
# 5f08705b08eca4ccfa851584
# 'entity_prepared'
# (624, 228)
# 5f087075ca90adc6e9322718
# ['real estate']
# new collection
# https://www.sec.gov/Archives/edgar/data/1660987/000110465920058926/tm2018788d1_-011.jpg
# (2165, 743)
# 5f0870a6921e7291c8c17d56
# 'entity_prepared'
# (714, 234)
# 5f0870aacd9aca81ef99c4df
# ['france', 'italy', 'germany', 'spain', 'commodities']
# new collection
# https://www.sec.gov/Archives/edgar/data/1809772/000149315220006617/form1-a_002.jpg
# (234, 118)
# 5f0870aa027e4c42b3bf71e1
# 'entity_prepared'
# (234, 118)
# 5f0870ac96de668b4b3dbfa5
# 'entity_prepared'
# (624, 219)
# 5f087100ca90adc6e9322719
# 'entity_prepared'
# (234, 118)
# 5f0871090ed882b716e68517
# 'entity_prepared'
# (359, 220)
# 5f087241f94f78449ee52fa7
# 'entity_prepared'
# (421, 255)
# 5f087242ca90adc6e932271a
# 'entity_prepared'
# (624, 223)
# 5f0872592f95d975b49b5be4
# 'entity_prepared'
# (484, 237)
# ...

# %%
import urllib.request
from PIL import Image

# %%
a = db_client["tweets_pipeline_v2"].find_one({"_id":bson.ObjectId(str("5f155abc45bdda693dd0280f"))})
print(a)
Image.open(urllib.request.urlopen(a['img_urls'])).size
# Out:
# {'_id': ObjectId('5f155abc45bdda693dd0280f'), 'search_text': 'continental resources "market share" 2020', 'exec_date': datetime.datetime(2020, 7, 20, 8, 41, 13, 792000), 'img_urls': 'https://assets.bwbx.io/images/users/iqjWHBFdfxIU/iabUctvkS5YU/v0/-1x-1.png', 'TIME_FIELD_FOR_SORTING': datetime.datetime(2020, 7, 20, 8, 41, 13, 792000), 'source': 'def', 'img_type': 'graphic', 'tech_type': 'norm', 'status': 'pipelined', 'extracted_text': 'Crude Curtailments Concho 1 Cimarex Diamondback | Other Chevron Exxon | ConocoPhillips Continental Мay June | 100 200 300 400 500 600 700 thousand Bloomberg', 'bert_tags': ['commodities', 'energy', 'oil'], 'industries_from_bert': ['Energy sources'], 'shifts_from_bert': ['Clean energy'], 'trasher': [], 'pipelined_ts': datetime.datetime(2020, 7, 20, 8, 50, 4, 748000), 'aws_answer': [{'Score': 0.6512324810028076, 'Type': 'COMMERCIAL_ITEM', 'Text': 'Concho 1', 'BeginOffset': 19, 'EndOffset': 27}, {'Score': 0.4205150306224823, 'Type': 'COMMERCIAL_ITEM', 'Te
# ...

# %%
import warnings
warnings.filterwarnings("ignore")
from collections import Counter
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MultiLabelBinarizer
import pymongo
import bson
import matplotlib.pyplot as plt
import matplotlib
import random
from itertools import permutations
from IPython.display import Image 
from IPython.core.display import Image, display
username = "tagger-admin"
password = "tvaiadmin"
db_client = pymongo.MongoClient('104.198.62.226', username=username,
                                password=password,
                                authSource='tags',
                                authMechanism='SCRAM-SHA-256', port=27017).tags


# # # In[20]:


# def CheckGraphicID(bson_id):
#     a = db_client["tweets_pipeline_v2"].find_one({"_id":bson.ObjectId(bson_id)})
#     if a is not None:
#         print("new collection")
#         if "validator_username" in a:
#             print(a["validator_username"])
            
# #         if "s3_url" in a:
# #             print(a['s3_url'])
# #             display(Image(a['s3_url'], unconfined=True))
# #         else:            
# #             print(a["img_urls"])
# #             display(Image(a['img_urls'], unconfined=True))
# #         print(a)
# #         return a
    
  
#         print(a["img_urls"])
#         display(Image(a['img_urls'], unconfined=True))
#         print(a)
#         return a

    
#     else:
#         print("old collection")
#         a = db_client["crawled_tweets"].find_one({"_id":bson.ObjectId(bson_id)})
#         print(a["validator_username"])
#         display(Image(a['s3_url'], unconfined=True))
#         return a

# %%
a = db_client["tweets_pipeline_v2"].find_one({"_id":bson.ObjectId("5f43ae49bb7913fc1676789a")})

# %%
a
# Out:
# {'_id': ObjectId('5f43ae49bb7913fc1676789a'),
#  'search_text': 'globus medical "market share" 2020',
#  'exec_date': datetime.datetime(2020, 8, 24, 11, 51, 46, 393000),
#  'img_urls': 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRnxdZ6ZimubDhKV2Clba7G_tEaW23UFTS-qw&usqp=CAU',
#  'TIME_FIELD_FOR_SORTING': datetime.datetime(2020, 8, 24, 11, 51, 46, 393000),
#  'source': 'google',
#  'img_type': 'graphic',
#  'tech_type': 'norm',
#  'status': 'pipelined',
#  'extracted_text': 'Globus Medical Revenue Growth Revenues S T00 $ 600 5 500 3400 S 300 S 200 $ 100 2017E de ing tr 2014 2015 2016 2018E',
#  'bert_tags': ['global', 'health'],
#  'industries_from_bert': ['Your health'],
#  'shifts_from_bert': ['Healthcare transformation'],
#  'trasher': [],
#  'pipelined_ts': datetime.datetime(2020, 8, 24, 12, 10, 49, 597000),
#  'aws_answer': [{'Score': 0.9438687562942505,
#    'Type': 'ORGANIZATION',
#    'Text': 'Globus Medical Revenue Growth Revenues',
#    'BeginOffset': 0,
# ...
