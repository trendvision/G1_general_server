# %%
from FindTag import FindTag

# %%
tag = "smartwatch"
FindTag(tag)
# Out:
# ID: 5df89e3a9477e636ee2d9da1
# Status graphicone_search
# ['smart device', 'smart watches', 'wearables', 'sports', 'fitness', 'technology', 'sales', 'sports watches', 'vr', 'smartwatch', 'virtual reality', 'electronics']
# grafeed_confirmed ['electronics', 'virtual reality', 'sports', 'technology', 'wearables', 'smartwatch']
# ID: 5e027840275a25100faaee97
# Status graphicone_search
# ['smart device', 'durables', 'wearables', 'sports', 'technology', 'consumer products', 'sport', 'consumer cyclicals', 'smartwatch', 'consumer discretionary', 'retail', 'consumer', 'electronics']
# grafeed_confirmed ['electronics', 'consumer', 'sports', 'retail', 'technology', 'wearables', 'consumer discretionary', 'smartwatch', 'consumer products']
# ID: 5e06b467de5db79623931d07
# Status graphicone_search
# ['smart device', 'technology', 'adidas', 'tv', 'tablet', 'gadgets', 'smartwatch', 'nike', 'jawbone up', 'computers', 'smartphone', 'sony', 'consumer', 'gaming', 'electronics']
# ...
